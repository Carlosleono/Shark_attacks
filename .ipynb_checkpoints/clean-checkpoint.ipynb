# %%
import pandas as pd
import matplotlib as plt
import seaborn as sns
from src import cleaning_functions as cf
import re
#import plotly.express as px
#import plotly.graph_objects as go

# %%
df = pd.read_csv('data/attacks.csv',encoding = "ISO-8859-1")
sharks=pd.DataFrame(df)
sharks.sample(5)
# Out:
#         Case Number  Date    Year     Type Country            Area  \
# 22115           NaN   NaN     NaN      NaN     NaN             NaN
# 23031           NaN   NaN     NaN      NaN     NaN             NaN
# 13185           NaN   NaN     NaN      NaN     NaN             NaN
# 6046   1847.00.00.b  1847  1847.0  Invalid     USA  South Carolina
# 7094              0   NaN     NaN      NaN     NaN             NaN
#
#                                    Location  Activity            Name Sex   \
# 22115                                   NaN       NaN             NaN  NaN
# 23031                                   NaN       NaN             NaN  NaN
# 13185                                   NaN       NaN             NaN  NaN
# 6046   Charleston Harbor, Charleston County  Swimming  a young sailor    M
# 7094                                    NaN       NaN             NaN  NaN
#
#        ...                                      Species   \
# 22115  ...                                           NaN
# 23031  ...                                           NaN
# 13185  ...                                           NaN
# 6046   ...  Shark involvement prior to death unconfirmed
# 7094   ...                                           NaN
#
#       Investigator or Source                      pdf  \
# 22115                    NaN                      NaN
# 23031                    NaN                      NaN
# 13185                    NaN                      NaN
# 6046   W.H. Gregg, pp. 21-22  1847.00.00.b-sailor.pdf
# 7094                     NaN                      NaN
#
#                                             href formula  \
# 22115                                                NaN
# 23031                                                NaN
# 13185                                                NaN
# 6046   http://sharkattackfile.net/spreadsheets/pdf_di...
# 7094                                                 NaN
#
#                                                     href Case Number.1  \
# 22115                                                NaN           NaN
# 23031                                                NaN           NaN
# 13185                                                NaN           NaN
# 6046   http://sharkattackfile.net/spreadsheets/pdf_di...  1847.00.00.b
# 7094                                                 NaN           NaN
#
#       Case Number.2 original order Unnamed: 22 Unnamed: 23
# 22115           NaN            NaN         NaN         NaN
# 23031           NaN            NaN         NaN         NaN
# 13185           NaN            NaN         NaN         NaN
# 6046   1847.00.00.b          257.0         NaN         NaN
# 7094            NaN            NaN         NaN         NaN
#
# [5 rows x 24 columns]

# %% [markdown]
# Thanks to a previous data review  which had been done in 'preliminary.ipynb' we know that we are not going to need the following columns of the dataset:
#
#     - Area
#     - Name
#     - Investigator or Source
#     - pdf
#     - href formula
#     - href
#     - Case Number.1
#     - Case Number.2
#     - original order
#     - Unnamed: 22
#     - Unnamed: 23

# %%
sharks.drop(['Area','Name','Investigator or Source','pdf','href formula','href','Case Number.1','Case Number.2','original order','Unnamed: 22','Unnamed: 23'], axis=1, inplace=True)
sharks.head()
# Out:
#   Case Number         Date    Year        Type    Country  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO
#
#                          Location     Activity Sex   Age  \
# 0     Oceanside, San Diego County     Paddling    F   57
# 1  St. Simon Island, Glynn County     Standing    F   11
# 2                    Habush, Oahu      Surfing    M   48
# 3              Arrawarra Headland      Surfing    M  NaN
# 4                        La Ticla  Free diving    M  NaN
#
#                                               Injury Fatal (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...           N
# 1                         Minor injury to left thigh           N
# 2       Injury to left lower leg from surfboard skeg           N
# 3                          Minor injury to lower leg           N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT           N
#
#             Time         Species
# 0          18h00      White shark
# 1  14h00  -15h00              NaN
# 2          07h45              NaN
# 3            NaN        2 m shark
# 4            NaN  Tiger shark, 3m

# %% [markdown]
# Now that we have just the information that we need we are going to check for NaNs and remove then. First, by removing all the rows that dont have any information (all NaN) and then by working on the others NaN

# %%
sharks.dropna(axis='index', thresh=12,inplace=True) #We have 13 columns left, if we have 12 NaNs in a row, the other is a 0 or is not relevant
sharks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2975 entries, 0 to 6265
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Case Number  2975 non-null   object
#  1   Date         2975 non-null   object
#  2   Year         2975 non-null   float64
#  3   Type         2975 non-null   object
#  4   Country      2975 non-null   object
#  5   Location     2962 non-null   object
#  6   Activity     2959 non-null   object
#  7   Sex          2967 non-null   object
#  8   Age          2744 non-null   object
#  9   Injury       2975 non-null   object
#  10  Fatal (Y/N)  2891 non-null   object
#  11  Time         2522 non-null   object
#  12  Species      2244 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 325.4+ KB

# %%
sharks.sample(10)
# Out:
#        Case Number         Date    Year        Type       Country  \
# 2657    1989.10.22  22-Oct-1989  1989.0  Unprovoked     AUSTRALIA
# 1888  2002.01.01.b  01-Jan-2002  2002.0  Unprovoked  SOUTH AFRICA
# 1788    2003.04.18  18-Apr-2003  2003.0  Unprovoked           USA
# 3868  1961.12.18.a  18-Dec-1961  1961.0  Unprovoked     AUSTRALIA
# 3638    1965.01.23  23-Jan-1965  1965.0  Unprovoked  SOUTH AFRICA
# 2190  1998.05.16.b  16-May-1998  1998.0  Unprovoked           USA
# 1902  2001.09.15.a  15-Sep-2001  2001.0  Unprovoked           USA
# 2372    1984.11.08  08-Nov-1984  1984.0  Unprovoked  SOUTH AFRICA
# 715     2012.12.25  25-Dec-2012  2012.0  Unprovoked  SOUTH AFRICA
# 363     2015.09.17  17-Sep-2015  2015.0  Unprovoked           USA
#
#                                       Location                       Activity  \
# 2657                             Shelly Point                         Surfing
# 1888                                  Mtunzini                    Surf skiing
# 1788  North Beach, Patrick AFB, Brevard County                        Surfing
# 3868                               Noosa Heads  Surfing, pushing board ashore
# 3638                Country Club Beach, Durban            Paddling rescue ski
# 2190            Walden Rocks, St. Lucie County             Swimming / surfing
# 1902        North Topsail Beach, Onslow County                        Surfing
# 2372                       Gonubie River Mouth                        Surfing
# 715                            Port St. John's                       Swimming
# 363           Jacksonville Beach, Duval County                        Surfing
#
#      Sex  Age                                             Injury Fatal (Y/N)  \
# 2657    M  17                            No injury, board bitten           N
# 1888    M  26                                 Foot & calf bitten           N
# 1788    M  12                        2 lacerations on left thigh           N
# 3868    M  22  FATAL, right wrist and hand bitten, left leg s...           Y
# 3638    M  22                              No injury, ski bitten           N
# 2190    M  24                         Left arm & wrist lacerated           N
# 1902    M  16                                        Foot bitten           N
# 2372    M  14                                  Wetsuit lacerated           N
# 715     M  20                                              FATAL           Y
# 363     M  20                               Injury to right foot           N
#
#         Time                                           Species
# 2657   14h20                             2.7 m [9'] white shark
# 1888  Sunset                                       Unidentified
# 1788   08h50                               Unidentified species
# 3868   06h15  Next morning a 3 m [10'] shark was caught that...
# 3638   13h00                          White shark, 3.7 m [12']
# 2190   15h00                                                NaN
# 1902   13h45                                                NaN
# 2372   17h00                                                NaN
# 715      NaN                                        Tiger shark
# 363    15h00                                                NaN

# %%
sns.countplot(x='Type',data=sharks)
sharks['Injury'].values[794]
# Out:
# 'Laceration to forearm'

# %%
sharks2=sharks[(sharks['Type'] == 'Boat')]
sharks2.sample(10)
# Out:
#        Case Number                  Date    Year  Type       Country  \
# 1168    2009.01.18           18-Jan-2009  2009.0  Boat     AUSTRALIA
# 538   2014.06.27.R  Reported 27-Jun-2014  2014.0  Boat    ST. MARTIN
# 4041    1959.12.03           03-Dec-1959  1959.0  Boat   NEW ZEALAND
# 1897  2001.09.30.a           30-Sep-2001  2001.0  Boat     AUSTRALIA
# 3451    1968.11.06           06-Nov-1968  1968.0  Boat  SOUTH AFRICA
# 3141    1977.08.19           19-Aug-1977  1977.0  Boat  SOUTH AFRICA
# 971   2010.11.12.R  Reported 12-Nov-2010  2010.0  Boat     AUSTRALIA
# 4035    1959.12.28           28-Dec-1959  1959.0  Boat     AUSTRALIA
# 1743  2003.09.14.b           14-Sep-2003  2003.0  Boat  SOUTH AFRICA
# 1995    2000.10.29           29-Oct-2000  2000.0  Boat     AUSTRALIA
#
#                                Location              Activity Sex       Age  \
# 1168                     Off Tower Hill               Fishing    M      NaN
# 538                 20 miles from shore  Transatlantic Rowing    M       48
# 4041                        Moko Hinau    Fishing for snapper    M      NaN
# 1897       Moreton Bay, NE of Brisbane                    NaN    M       31
# 3451                           Ramsgate               Fishing    M       22
# 3141                 Off Macassar Beach               Fishing    M      NaN
# 971   Between Carnac and Garden Islands               Fishing    M      NaN
# 4035                  Leichardt, Sydney               Fishing  NaN  50 & 30
# 1743                      Melkbosstrand              Fishing   NaN  36 & 26
# 1995                        Peel Island              Fishing   NaN       31
#
#                                                  Injury Fatal (Y/N)  \
# 1168        No injury to occupants, shark bit propeller           N
# 538                       His boat was holed by a shark           N
# 4041           No injury to occupant, shark sank dinghy           N
# 1897                               No injury from shark           N
# 3451  Shark leapt into boat, landed on Hlope's back,...           N
# 3141  Shark leapt into boat, pinning Mamacos beneath...           N
# 971   No injury to occupant. Shark rammed bottom of ...           N
# 4035                             No injury to occupants           N
# 1743             No injury to occupants, shark bit boat           N
# 1995   No Injury to occupant, shark holed and sank boat           N
#
#             Time                 Species
# 1168       09h20      White shark, 5.5 m
# 538          NaN  Oceanic whitetip shark'
# 4041       14h00  Mako shark, 4.3 m [14']
# 1897        P.M.    4 m [13'] white shark
# 3451         NaN   90-kg "blackfin" shark
# 3141       13h30              White shark
# 971        Night              White shark
# 4035  Late night        2.4 m  [8'] shark
# 1743       09h40            2 m cow shark
# 1995       22h00              White shark

# %% [markdown]
# We are going to generate a column 'Months' based on the month expressed in 'Case Number' and we want it to be a float

# %%
sharks['Month'] = sharks['Case Number'].str.extract(r'(\.\w+\.)')
sharks['Month'] = sharks.Month.str.extract(r'(\w+)')
sharks.Month.fillna(00,inplace=True)
monthfloat=sharks.Month.astype({'Month':int})
sharks['Month'] = monthfloat
sharks.sample(5)
# Out:
#        Case Number          Date    Year        Type       Country  \
# 1225    2008.07.27   27-Jul-2008  2008.0  Unprovoked        PANAMA
# 1035    2010.03.27   27-Mar-2010  2010.0  Unprovoked       REUNION
# 147   2017.04.29.c   29-Apr-2017  2017.0  Unprovoked  SOUTH AFRICA
# 2838    1985.10.22   22-Oct-1985  1985.0  Unprovoked           USA
# 2860    1985.01.27   27-Jan-1985  1985.0  Unprovoked  SOUTH AFRICA
#
#                                     Location                   Activity Sex   \
# 1225                              Playa Teta        Swimming or surfing    M
# 1035                                 Bittern                    Surfing    M
# 147               Keurbooms, Plettenberg Bay                    Surfing    M
# 2838  Point Conception, Santa Barbara County  Hookah diving for abalone    M
# 2860                              Struisbaai                   Swimming    M
#
#       Age                                Injury Fatal (Y/N)   Time  \
# 1225  NaN            5 lacerations to left foot           N  18h00
# 1035   34               No injury, board bitten           N  11h00
# 147    14            Minor injury to right calf           N  17h10
# 2838   46          Minor injury to foot & ankle           N  16h00
# 2860   15  Right knee, calf and ankle lacerated           N  18h30
#
#                                                Species   Month
# 1225                                          3'  shark      7
# 1035                                        1.5 m shark      3
# 147                                                 NaN      4
# 2838  2 m to 2.5 m [6.75'  to 8.25'] sixgill or seve...     10
# 2860                                  Raggedtooth shark      1

# %%
sns.countplot(x='Month',data=sharks)
# Out:
# <AxesSubplot:xlabel='Month', ylabel='count'>

# %% [markdown]
# Now we are going to normalize 'Activity' and 'Type' columns for them to have less values. We are going to do so by gruping similar values.
#
# For type, we are going to distinguish between Provoked and Unprovoked. As seen in the data, most of the boat and sea disaster are unprovoked and we are going to characterize the ones which are questionable as unprovoked, giving sharks the benefit of the doubt.

# %%
sharks.Type.unique()
# Out:
# array(['Boating', 'Unprovoked', 'Invalid', 'Provoked', 'Questionable',
#        'Boat', 'Sea Disaster'], dtype=object)

# %%
sharks['Type'].values[1]
# Out:
# 'Unprovoked'

# %%
sharks['Type_Norm'] = sharks.Type.apply(lambda x: 'Unprovoked' if (x == 'Boating') | (x== 'Boat') |(x == 'Unprovoked') |(x == 'Invalid') |(x == 'Questionable') |(x== 'Sea Disaster') else 'Provoked')
sharks.sample(3)
# Out:
#        Case Number         Date    Year        Type Country  \
# 1020  2010.06.25.a  25-Jun-2010  2010.0  Unprovoked     USA
# 1954  2001.04.13.a  13-Apr-2001  2001.0  Unprovoked     USA
# 3521    1967.07.29  29-Jul-1967  1967.0  Unprovoked     USA
#
#                               Location    Activity Sex  Age  \
# 1020     Topsail Island, Pender County    Swimming    F  13
# 1954  New Smyrna Beach, Volusia County     Surfing    M  12
# 3521                      Florida Keys  Snorkeling    M  20
#
#                             Injury Fatal (Y/N)       Time  \
# 1020       Laceration to left foot           N      13h00
# 1954  Right foot & ankle lacerated           N      10h55
# 3521                Foot lacerated           N  Afternoon
#
#                                            Species   Month   Type_Norm
# 1020                                            NaN      6  Unprovoked
# 1954  Possibly a juvenile blacktip or spinner shark      4  Unprovoked
# 3521                                            NaN      7  Unprovoked

# %%
sns.countplot(x='Type_Norm',data=sharks)
# Out:
# <AxesSubplot:xlabel='Type_Norm', ylabel='count'>

# %%
def surf(x):
    return re.sub('.*urf.*|.*Paddl.*|.*board.*|.*Board.*|.*surf.*|.+Surf.*','Surfing',x)

def dive(x):
    return re.sub('.*Dive|.*iv.*|Scuba|nork','Diving',x)

def swim(x):
    return re.sub('Swim.*|.*swim.*|Swimming|Wad|Bath.*|float.*|Float.*|\sSwim.*','Swimming',x)

def fish(x):
    return re.sub('fish.*|Fish.*|.*fish','Fishing',x)

def boat(x):
    return re.sub('.*boat.*|.*Boat.*|Canoe.*|Sailing','Boat',x)

def other(x):
    return re.sub('.*[^Surf][^Diving][^Swimming][^Fishing][^Boat].*','Other',x)

# %%
#We are going to unify all the surf relataed activities into one 'Surf'
sharks.Activity=sharks.Activity.map(surf,na_action='ignore')

#We are going to unify all the dive relataed activities into one 'Diving'
sharks.Activity=sharks.Activity.map(dive,na_action='ignore')
#We are going to unify all the swim relataed activities into one 'Swimming'
sharks.Activity=sharks.Activity.map(swim,na_action='ignore')
#We are going to unify all the fishing relataed activities into one 'Fishing'
sharks.Activity=sharks.Activity.map(fish,na_action='ignore')

#We are going to unify all the boat relataed activities into one 'Boat'
sharks.Activity=sharks.Activity.map(boat,na_action='ignore')

#We are going to unify the rest in a category called 'Other'
sharks.Activity=sharks.Activity.map(other,na_action='ignore')


#Now that only a few values are left, we are going to introduce them into the 'Other' category by using replace
sharks.Activity.replace(['Standing','Swimminging','SDivingeling','Fishinging','SUP','Rowing','Filming', 'Swimminge Fishing', 'Swimminging?', 'Jumping',
       'Fishinging net', 'Unknown', 'RidingSwimming', '   ',
       'Fishinging ', 'Sitting', 'Fishinging using Diving', 'Splashing',
       'Fishing ', 'Fishinging on Diving', 'Washing', 'Splashing '],'Other',inplace=True)
sharks.Activity.fillna('Other',inplace=True)

sharks.Activity.unique()
# Out:
# array(['Surfing', 'Other', 'Swimming', 'Fishing', 'Diving', 'Boat',
#        'Riding Swimming'], dtype=object)

# %%
sns.countplot(x='Activity',data=sharks)
# Out:
# <AxesSubplot:xlabel='Activity', ylabel='count'>

# %%
#Lets fix column 'Species ' to 'Species'
sharks.rename(columns={'Species ':'Species'},inplace=True)

# %%
sharks.Species.unique()
# Out:
# array(['White shark', nan, 'Tiger shark', ..., 'White sharks',
#        "Nurse shark, 2.1 m [7'] ", '"A pack of sharks"'], dtype=object)

# %%
def white(x):
    return re.sub('.*White.*|.*white.*','White shark',x)
def tiger(x):
    return re.sub('.*Tiger.*|.*tiger.*','Tiger Shark',x)
def lemon(x):
    return re.sub('.*Lemon.*|.*lemon.*','Nurse Shark',x)
def bull(x):
    return re.sub('.*Bull.*|.*bull.*','Bull Shark',x)
def mako(x):
    return re.sub('.*Mako.*|.*mako.*','Mako Shark',x)
def blue(x):
    return re.sub('.*Blue.*|.*blue.*','Blue Shark',x)
def blacktip(x):
    return re.sub('.*blacktip.*|.*Blacktip.*','Blacktip reef Shark',x)
def hammerhead(x):
    return re.sub('.*Hammerhead.*|.*hammerhead.*','Hammerhead Shark',x)
def nurse(x):
    return re.sub('.*Nurse.*|.*nurse.*','Nurse Shark',x)
def whaler(x):
    return re.sub('.*Whaler.*|.*whaler.*','Bronze Whaler Shark',x)
def caribbean(x):
    return re.sub('.*Caribbean.*|.*caribbean.*','Caribbean Reef Shark',x)
def raggedtooth(x):
    return re.sub('.*Raggedtooth.*|.*raggedtooth.*','Raggedtooth Shark',x)
def spinner(x):
    return re.sub('.*Spinner.*|.*spinner.*','Spinner Shark',x)

# %%
sharks.Species=sharks.Species.map(white,na_action='ignore')
sharks.Species=sharks.Species.map(tiger,na_action='ignore')
sharks.Species=sharks.Species.map(lemon,na_action='ignore')
sharks.Species=sharks.Species.map(bull,na_action='ignore')
sharks.Species=sharks.Species.map(mako,na_action='ignore')
sharks.Species=sharks.Species.map(blue,na_action='ignore')
sharks.Species=sharks.Species.map(blacktip,na_action='ignore')
sharks.Species=sharks.Species.map(hammerhead,na_action='ignore')
sharks.Species=sharks.Species.map(nurse,na_action='ignore')
sharks.Species=sharks.Species.map(whaler,na_action='ignore')
sharks.Species=sharks.Species.map(caribbean,na_action='ignore')
sharks.Species=sharks.Species.map(raggedtooth,na_action='ignore')
sharks.Species=sharks.Species.map(spinner,na_action='ignore')

sharknames = ['White Shark','Tiger Shark','Nurse Shark','Bull Shark', 'Mako Shark','Blue Shark','Blacktip reef Shark','Hammerhead Shark','Nurse Shark','Bronze Whaler Shark', 'Caribbean Reef Shark', 'Raggedtooth Shark','Spinner Shark']
for i in range(0,len(sharks.Species)):
    if sharks['Species'].values[i] not in sharknames:
        sharks['Species'].values[i]='Unidentified'

# %%
for i in range(0,len(sharks['Fatal (Y/N)'])):
    if sharks['Fatal (Y/N)'].values[i] == 'M':
        sharks['Fatal (Y/N)'].values[i] = 0
    elif sharks['Fatal (Y/N)'].values[i] == '2017':
        sharks['Fatal (Y/N)'].values[i] = 0
    elif sharks['Fatal (Y/N)'].values[i] == ' N':
        sharks['Fatal (Y/N)'].values[i] = 0
    elif sharks['Fatal (Y/N)'].values[i] == 'UNKNOWN':
        sharks['Fatal (Y/N)'].values[i] = 0
    elif sharks['Fatal (Y/N)'].values[i] == 'N':
        sharks['Fatal (Y/N)'].values[i] = 0
    else:
        sharks['Fatal (Y/N)'].values[i] = 1
sharks['Fatal (Y/N)'].fillna('UNKNOWN',inplace=True)

# %%
sharks['Fatal (Y/N)'].unique()
# Out:
# array([0, 1])

# %%
sharks.rename(columns = {'Fatal (Y/N)':'Fatal'},inplace=True)

# %%
sharks.rename(columns={'Sex ':'Sex'},inplace=True)

# %%
sharks.Sex.replace(to_replace = 'M ', value='M',inplace=True)
sharks.Sex.replace(to_replace = 'lli', value='unknown',inplace=True)
sharks.Sex.fillna('unknown',inplace=True)

# %%
sharks.Sex.unique()
# Out:
# array(['F', 'M', 'unknown'], dtype=object)

# %%
sharks.Country.unique()
# Out:
# array(['USA', 'BRAZIL', 'AUSTRALIA', 'ENGLAND', 'COSTA RICA', 'MALDIVES',
#        'SOUTH AFRICA', 'THAILAND', 'BAHAMAS', 'ECUADOR', 'NEW CALEDONIA',
#        'MALAYSIA', 'CUBA', 'NEW ZEALAND', 'SPAIN', 'JAPAN', 'EGYPT',
#        'ST HELENA, British overseas territory', 'MEXICO', 'REUNION',
#        'UNITED KINGDOM', 'UNITED ARAB EMIRATES', 'PHILIPPINES',
#        'INDONESIA', 'COLUMBIA', 'FRENCH POLYNESIA', 'MOZAMBIQUE',
#        'PUERTO RICO', 'ST. MARTIN', 'FRANCE', 'ISRAEL',
#        'PALESTINIAN TERRITORIES', 'JAMAICA', 'TONGA', 'SCOTLAND', 'ITALY',
#        'TAIWAN', 'PAPUA NEW GUINEA', 'RUSSIA', 'SEYCHELLES',
#        'TURKS & CAICOS', 'FIJI', 'DOMINICAN REPUBLIC', 'SOUTH KOREA',
#        'MALTA', 'VIETNAM', 'MADAGASCAR', 'GUAM',
#        'UNITED ARAB EMIRATES (UAE)', 'PANAMA', 'CROATIA',
#        'SOLOMON ISLANDS', 'NORWAY', 'ST. MAARTIN', 'GRAND CAYMAN',
#        'CHINA', 'VANUATU', 'URUGUAY', 'VENEZUELA', 'INDIA', 'MICRONESIA',
#        'CANADA', 'OKINAWA', 'TANZANIA', ' TONGA', 'MARSHALL ISLANDS',
#        'MAURITIUS', 'SENEGAL', 'EGYPT / ISRAEL', 'HONG KONG', 'CHILE',
#        'CARIBBEAN SEA', 'KENYA', 'NORTH ATLANTIC OCEAN', 'PORTUGAL',
#        'WESTERN SAMOA', 'BRITISH ISLES', 'PALAU', 'GRENADA', 'IRAQ',
#        'BERMUDA', 'TURKEY', 'SINGAPORE', 'NEW BRITAIN', 'PACIFIC OCEAN ',
#        'NEW GUINEA', 'FEDERATED STATES OF MICRONESIA', 'GREECE',
#        'BRITISH WEST INDIES', 'MID ATLANTIC OCEAN', 'PERSIAN GULF',
#        'NORTH PACIFIC OCEAN', 'NORTH SEA', 'NICARAGUA ', 'AMERICAN SAMOA',
#        'ANDAMAN / NICOBAR ISLANDAS', 'PACIFIC OCEAN', 'ARGENTINA',
#        'SUDAN', 'EL SALVADOR', 'IRAN', 'SOUTH ATLANTIC OCEAN',
#        'TRINIDAD & TOBAGO', 'HAITI', 'NICARAGUA', 'CYPRUS', 'EGYPT ',
#        'YEMEN ', 'GUINEA', 'SRI LANKA', 'BARBADOS'], dtype=object)

# %%
sns.countplot(x='Country',data=sharks)

#eliminar todos los que salgan solo una vez
# Out:
# <AxesSubplot:xlabel='Country', ylabel='count'>

# %%
sharks.Country.value_counts()['USA']
new_index = range(0,2974)
sharks.reset_index(inplace=True)
sharks.head()
# Out:
#    index   Case Number         Date    Year        Type Country  \
# 0      0    2018.06.25  25-Jun-2018  2018.0     Boating     USA
# 1      1    2018.06.18  18-Jun-2018  2018.0  Unprovoked     USA
# 2      2    2018.06.09  09-Jun-2018  2018.0     Invalid     USA
# 3      6  2018.06.03.a  03-Jun-2018  2018.0  Unprovoked  BRAZIL
# 4      7    2018.05.27  27-May-2018  2018.0  Unprovoked     USA
#
#                                             Location  Activity Sex Age  \
# 0                        Oceanside, San Diego County   Surfing   F  57
# 1                     St. Simon Island, Glynn County     Other   F  11
# 2                                       Habush, Oahu   Surfing   M  48
# 3                              Piedade Beach, Recife  Swimming   M  18
# 4  Lighhouse Point Park, Ponce Inlet, Volusia County   Fishing   M  52
#
#                                               Injury  Fatal            Time  \
# 0  No injury to occupant, outrigger canoe and pad...      0           18h00
# 1                         Minor injury to left thigh      0   14h00  -15h00
# 2       Injury to left lower leg from surfboard skeg      0           07h45
# 3                                              FATAL      1  Late afternoon
# 4            Minor injury to foot. PROVOKED INCIDENT      0             NaN
#
#         Species  Month   Type_Norm
# 0  Unidentified      6  Unprovoked
# 1  Unidentified      6  Unprovoked
# 2  Unidentified      6  Unprovoked
# 3   Tiger Shark      6  Unprovoked
# 4   Nurse Shark      5  Unprovoked

# %%
for i in range(0,len(sharks.Country)):
    country=[sharks.Country[i]]
    
    cuenta=sharks.Country.value_counts()[country[0]]
    
    if  cuenta<= 2:
        sharks.Country[i] = 'OTHER'
# Out:
# <ipython-input-30-e62058a7fc6d>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.Country[i] = 'OTHER'

# %%
sharks.Country.value_counts()
# Out:
# USA                 1384
# AUSTRALIA            638
# SOUTH AFRICA         355
# OTHER                 69
# BAHAMAS               53
# NEW ZEALAND           47
# BRAZIL                42
# REUNION               35
# MEXICO                31
# PAPUA NEW GUINEA      23
# MOZAMBIQUE            21
# NEW CALEDONIA         19
# FIJI                  16
# EGYPT                 16
# ITALY                 15
# SPAIN                 14
# FRENCH POLYNESIA      12
# JAPAN                 12
# PANAMA                10
# IRAQ                   9
# CROATIA                9
# CUBA                   7
# PHILIPPINES            7
# INDONESIA              6
# TONGA                  6
# TAIWAN                 6
# ECUADOR                6
# JAMAICA                5
# CHILE                  5
# UNITED KINGDOM         5
# GREECE                 5
# SENEGAL                5
# BERMUDA                5
# THAILAND               4
# NEW BRITAIN            4
# ENGLAND                4
# COLUMBIA               4
# COSTA RICA             4
# PACIFIC OCEAN          4
# HONG KONG              4
# SOUTH KOREA            4
# MARSHALL ISLANDS       4
# INDIA                  4
# VIETNAM                4
# VENEZUELA              3
# TURKS & CAICOS         3
# GUAM                   3
# SCOTLAND               3
# OKINAWA                3
# VANUATU                3
# SOLOMON ISLANDS        3
# MICRONESIA             3
# GRENADA                3
# KENYA                  3
# PALAU                  3
# Name: Country, dtype: int64

# %%
sharks.sample()
# Out:
#       index Case Number         Date    Year      Type Country  \
# 2775   4795  1939.07.14  14-Jul-1939  1939.0  Provoked     USA
#
#                                Location Activity Sex  Age  \
# 2775  West Bay, 19 miles from Galveston    Other   M  NaN
#
#                                             Injury  Fatal     Time  \
# 2775  Leg bitten by snared shark PROVOKED INCIDENT      0  Morning
#
#            Species  Month Type_Norm
# 2775  Unidentified      7  Provoked

# %%
sharks.drop(['index', 'Case Number', 'Type', 'Location', 'Time'],axis=1,inplace=True)

# %%
yearint=sharks.Year.astype({'Year':int})
sharks['Year'] = yearint
sharks.sample()
sharks=sharks[['Date','Year','Month','Country','Activity','Type_Norm','Sex','Age','Species','Fatal']]
sharks.sample(5)
# Out:
#              Date  Year  Month      Country Activity   Type_Norm Sex Age  \
# 1756  04-Dec-1991  1991     12          USA   Diving  Unprovoked   M  25
# 864   28-Jun-2008  2008      6      BAHAMAS    Other  Unprovoked   M  42
# 2266  09-Mar-1967  1967      3  NEW ZEALAND    Other  Unprovoked   M  21
# 956   17-Jul-2007  2007      7          USA    Other  Unprovoked   F  30
# 2709  14-Nov-1947  1947     11    AUSTRALIA  Surfing  Unprovoked   M  16
#
#            Species  Fatal
# 1756  Unidentified      0
# 864     Bull Shark      0
# 2266  Unidentified      1
# 956   Unidentified      0
# 2709  Unidentified      0

# %%
countries= sharks.Country.unique()
sharks.Country.replace(to_replace='ENGLAND',value='UNITED KINGDOM',inplace=True)
sharks.Country.replace(to_replace='SCOTLAND',value='UNITED KINGDOM',inplace=True)
sharks.Country.replace(to_replace='NEW BRITAIN',value='USA',inplace=True)
sharks.Country.replace(to_replace='PACIFIC OCEAN',value='OTHER',inplace=True)


countries
# Out:
# array(['USA', 'BRAZIL', 'AUSTRALIA', 'ENGLAND', 'COSTA RICA', 'OTHER',
#        'SOUTH AFRICA', 'THAILAND', 'BAHAMAS', 'ECUADOR', 'NEW CALEDONIA',
#        'CUBA', 'NEW ZEALAND', 'SPAIN', 'JAPAN', 'EGYPT', 'MEXICO',
#        'REUNION', 'UNITED KINGDOM', 'PHILIPPINES', 'INDONESIA',
#        'COLUMBIA', 'FRENCH POLYNESIA', 'MOZAMBIQUE', 'JAMAICA', 'TONGA',
#        'SCOTLAND', 'ITALY', 'TAIWAN', 'PAPUA NEW GUINEA',
#        'TURKS & CAICOS', 'FIJI', 'SOUTH KOREA', 'VIETNAM', 'GUAM',
#        'PANAMA', 'CROATIA', 'SOLOMON ISLANDS', 'VANUATU', 'VENEZUELA',
#        'INDIA', 'MICRONESIA', 'OKINAWA', 'MARSHALL ISLANDS', 'SENEGAL',
#        'HONG KONG', 'CHILE', 'KENYA', 'PALAU', 'GRENADA', 'IRAQ',
#        'BERMUDA', 'NEW BRITAIN', 'GREECE', 'PACIFIC OCEAN'], dtype=object)

# %%
northhem = ['USA','ENGLAND', 'COSTA RICA', 'OTHER', 'BAHAMAS', 'ECUADOR','CUBA', 'SPAIN', 'MEXICO', 'UNITED KINGDOM'
        , 'PHILIPPINES', 'JAPAN', 'COLUMBIA',
       'EGYPT', 'JAMAICA', 'SCOTLAND', 'ITALY', 'TAIWAN', 
       'TURKS & CAICOS', 'VIETNAM', 'GUAM',
       'PANAMA', 'CROATIA', 'VENEZUELA',
       'INDIA', 'OKINAWA', 'MARSHALL ISLANDS', 'SENEGAL',
       'HONG KONG', 'PALAU', 'GRENADA', 'IRAQ',
       'BERMUDA', 'NEW BRITAIN', 'GREECE', 'PACIFIC OCEAN']
sourthhem = []
for i in range(0,len(sharks.Country)):
    country=sharks.Country[i]
    if sharks.Country[i] not in northhem:
        if sharks.Country[i] not in sourthhem:
            sourthhem.append(country)
sourthhem
# Out:
# ['BRAZIL',
#  'AUSTRALIA',
#  'SOUTH AFRICA',
#  'THAILAND',
#  'NEW CALEDONIA',
#  'NEW ZEALAND',
#  'REUNION',
#  'INDONESIA',
#  'FRENCH POLYNESIA',
#  'MOZAMBIQUE',
#  'TONGA',
#  'PAPUA NEW GUINEA',
#  'FIJI',
#  'SOUTH KOREA',
#  'SOLOMON ISLANDS',
#  'VANUATU',
#  'MICRONESIA',
#  'CHILE',
#  'KENYA']

# %%
hemisphere = []
for i in range(0,len(sharks.Country)):
    country=sharks.Country[i]
    if sharks.Country[i] not in northhem:
        hemisphere.append('Southern')
    else:
        hemisphere.append('Northern')
sharks['Hemisphere']=hemisphere
sharks.sample(10)
# Out:
#              Date  Year  Month       Country  Activity   Type_Norm Sex  \
# 2653     Apr-1952  1952      4         OTHER     Other    Provoked   M
# 1147  06-Oct-2004  2004     10       REUNION   Surfing  Unprovoked   M
# 2332  18-Nov-1964  1964     11     AUSTRALIA  Swimming  Unprovoked   M
# 92    17-Jun-2017  2017      6         SPAIN  Swimming  Unprovoked   M
# 2390  13-Apr-1963  1963      4     AUSTRALIA   Surfing  Unprovoked   M
# 518   25-Sep-2012  2012      9           USA   Surfing  Unprovoked   M
# 2403  28-Oct-1962  1962     10  SOUTH AFRICA     Other  Unprovoked   M
# 191   31-May-2016  2016      5     AUSTRALIA   Surfing  Unprovoked   M
# 2373  28-Nov-1963  1963     11          FIJI   Fishing  Unprovoked   F
# 1720  04-Jan-1993  1993      1         OTHER     Other  Unprovoked   M
#
#           Age       Species  Fatal Hemisphere
# 2653      NaN  Unidentified      0   Northern
# 1147       15   Tiger Shark      0   Southern
# 2332       29  Unidentified      1   Southern
# 92         82  Unidentified      0   Northern
# 2390       25  Unidentified      0   Southern
# 518        21  Unidentified      0   Northern
# 2403       30  Unidentified      0   Southern
# 191        29  Unidentified      1   Southern
# 2373       21   Tiger Shark      0   Southern
# 1720  32 & 30  Unidentified      0   Northern

# %%
#sharks=sharks[['Date','Year','Month','Country','Hemisphere','Activity','Type_Norm','Sex','Species','Fatal']]
sharks.sample(10)
# Out:
#              Date  Year  Month       Country  Activity   Type_Norm Sex Age  \
# 2141  04-Apr-1974  1974      4  SOUTH AFRICA   Surfing  Unprovoked   M  17
# 1378  12-Jun-2001  2001      6           USA  Swimming  Unprovoked   M  14
# 697   07-Aug-2010  2010      8         OTHER   Surfing  Unprovoked   M  35
# 2204        1970s  1970      0          IRAQ     Other  Unprovoked   F  28
# 926   16-Sep-2007  2007      9           USA     Other  Unprovoked   M  56
# 36    01-Feb-2018  2018      2     AUSTRALIA     Other  Unprovoked   M  14
# 1306  20-Jul-2002  2002      7           USA  Swimming  Unprovoked   F  15
# 124   11-Feb-2017  2017      2           USA  Swimming  Unprovoked   M  22
# 587   23-Dec-2011  2011     12           USA   Surfing  Unprovoked   M  27
# 1195  25-Jan-2004  2004      1     AUSTRALIA    Diving  Unprovoked   M  46
#
#            Species  Fatal Hemisphere
# 2141  Unidentified      0   Southern
# 1378  Unidentified      0   Northern
# 697   Unidentified      0   Northern
# 2204  Unidentified      0   Northern
# 926   Unidentified      0   Northern
# 36    Unidentified      0   Southern
# 1306    Bull Shark      0   Northern
# 124   Unidentified      0   Northern
# 587   Unidentified      0   Northern
# 1195  Unidentified      0   Southern

# %%
sharks.Age.unique()
# Out:
# array(['57', '11', '48', '18', '52', '15', '12', '32', '10', '21', '34',
#        nan, '30', '60', '33', '29', '54', '37', '56', '19', '25', '69',
#        '38', '55', '35', '46', '45', '14', '40s', '28', '20', '24', '26',
#        '49', '22', '7', '31', '17', '40', '13', '42', '3', '50', '82',
#        '41', '20s', '51', '39', '58', '47', '16', '61', '65', '73', '36',
#        '66', '43', '60s', '9', '59', '6', '27', '64', '23', '71', '44',
#        '62', '68', '63', '70', '18 months', '53', '30s', '8', 'Teen',
#        'teen', '77', '74', '28 & 26', '5', '86', '18 or 20', '12 or 13',
#        '36 & 26', '8 or 10', '84', '\xa0 ', ' ', '30 or 36', '6½',
#        '21 & ?', '33 or 37', ' 30', ' 28', '20?', "60's", '32 & 30', '67',
#        '75', '21 or 26', '20 ', '>50', 'adult', '9 & 12', '? & 19',
#        '25 to 35', '23 & 26', '(adult)', '33 & 37', '25 or 28',
#        '21, 34,24 & 35', '30 & 32', '50 & 30', '17 & 35', '13 or 18',
#        '33 & 26', 'MAKE LINE GREEN', ' 43', '"young"', '7 or 8', 'F',
#        'Both 11', '9 or 10', '  ', '31 or 33', '13 or 14'], dtype=object)

# %%
def age(x):
    return re.sub('.*[a-zA-Z!@#$%^&*()_+\-=\[\]{};\\|,.<>\/?].*|.*\s.*','0',x)

# %%
sharks.Age=sharks.Age.map(age,na_action='ignore')
sharks.Age.unique()
sharks.Age.replace(to_replace='6½',value='0',inplace=True)
sharks.Age.unique()
sharks.Age.fillna('0',inplace=True)
sharks.Age.unique()
sharks.Age.replace(to_replace='nan',value='0',inplace=True)
sharks.info()
sharks.Age.astype(int)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2975 entries, 0 to 2974
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        2975 non-null   object
#  1   Year        2975 non-null   int64
#  2   Month       2975 non-null   int64
#  3   Country     2975 non-null   object
#  4   Activity    2975 non-null   object
#  5   Type_Norm   2975 non-null   object
#  6   Sex         2975 non-null   object
#  7   Age         2975 non-null   object
#  8   Species     2975 non-null   object
#  9   Fatal       2975 non-null   int64
#  10  Hemisphere  2975 non-null   object
# dtypes: int64(3), object(8)
# memory usage: 255.8+ KB
# 0       57
# 1       11
# 2       48
# 3       18
# 4       52
#         ..
# 2970    36
# 2971    25
# 2972     6
# 2973    16
# 2974     0
# Name: Age, Length: 2975, dtype: int64

# %%
sharks['YearRange']=sharks.Year
for i in range(0,len(sharks.Year)):
    if sharks.Year[i] < 1860:
        sharks.YearRange[i]=1850
    elif sharks.Year[i] < 1870:
        sharks.YearRange[i]=1860
    elif sharks.Year[i] < 180:
        sharks.YearRange[i]=1870
    elif sharks.Year[i] < 1880:
        sharks.YearRange[i]=1870
    elif sharks.Year[i] < 1890:
        sharks.YearRange[i]=1880
    elif sharks.Year[i] < 1900:
        sharks.YearRange[i]=1890
    elif sharks.Year[i] < 1910:
        sharks.YearRange[i]=1900
    elif sharks.Year[i] < 1920:
        sharks.YearRange[i]=1910
    elif sharks.Year[i] < 1930:
        sharks.YearRange[i]=1920
    elif sharks.Year[i] < 1940:
        sharks.YearRange[i]=1930
    elif sharks.Year[i] < 1950:
        sharks.YearRange[i]=1940
    elif sharks.Year[i] < 1960:
        sharks.YearRange[i]=1950
    elif sharks.Year[i] < 1970:
        sharks.YearRange[i]=1960
    elif sharks.Year[i] < 1980:
        sharks.YearRange[i]=1970
    elif sharks.Year[i] < 1990:
        sharks.YearRange[i]=1980
    elif sharks.Year[i] < 2000:
        sharks.YearRange[i]=1990
    elif sharks.Year[i] < 2010:
        sharks.YearRange[i]=2000
    elif sharks.Year[i] < 2020:
        sharks.YearRange[i]=2010
    elif sharks.Year[i] < 2030:
        sharks.YearRange[i]=2020
# Out:
# <ipython-input-45-4ed7cac550ed>:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=2010
# <ipython-input-45-4ed7cac550ed>:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=2000
# <ipython-input-45-4ed7cac550ed>:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1990
# <ipython-input-45-4ed7cac550ed>:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1980
# <ipython-input-45-4ed7cac550ed>:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1970
# <ipython-input-45-4ed7cac550ed>:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1960
# <ipython-input-45-4ed7cac550ed>:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1950
# <ipython-input-45-4ed7cac550ed>:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1940
# <ipython-input-45-4ed7cac550ed>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1930
# <ipython-input-45-4ed7cac550ed>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1920
# <ipython-input-45-4ed7cac550ed>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1910
# <ipython-input-45-4ed7cac550ed>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1900
# <ipython-input-45-4ed7cac550ed>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1890
# <ipython-input-45-4ed7cac550ed>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1880
# <ipython-input-45-4ed7cac550ed>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1870
# <ipython-input-45-4ed7cac550ed>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1860
# <ipython-input-45-4ed7cac550ed>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sharks.YearRange[i]=1850

# %%
sharks=sharks[['Year','Month','Country','Hemisphere','Activity','Type_Norm','Sex','Age','Species','Fatal','YearRange']]
sharks.to_csv('data/sharks_clean.csv')
